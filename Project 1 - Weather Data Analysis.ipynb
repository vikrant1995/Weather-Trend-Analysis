# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
sns.set()

# %%
def copy_csv(filename):
    import pandas as pd
    df = pd.read_csv(filename)
    df.to_csv('copy_of_' + filename)

# %%
copy_csv('New Delhi Data.csv')

# %%
NewDelhi_Data = pd.read_csv('copy_of_New Delhi Data.csv', index_col = 0)

# %%
NewDelhi_Data.head()
# Out:
#    year       city country  avg_temp
# 0  1796  New Delhi   India     25.03
# 1  1797  New Delhi   India     26.71
# 2  1798  New Delhi   India     24.29
# 3  1799  New Delhi   India     25.28
# 4  1800  New Delhi   India     25.21

# %%
NewDelhi_Data.describe()
# Out:
#               year    avg_temp
# count   218.000000  201.000000
# mean   1904.500000   25.166269
# std      63.075352    0.594003
# min    1796.000000   23.700000
# 25%    1850.250000   24.800000
# 50%    1904.500000   25.140000
# 75%    1958.750000   25.550000
# max    2013.000000   26.710000

# %%
NewDelhi_Data
# Out:
#      year       city country  avg_temp
# 0    1796  New Delhi   India     25.03
# 1    1797  New Delhi   India     26.71
# 2    1798  New Delhi   India     24.29
# 3    1799  New Delhi   India     25.28
# 4    1800  New Delhi   India     25.21
# 5    1801  New Delhi   India     24.22
# 6    1802  New Delhi   India     25.63
# 7    1803  New Delhi   India     25.38
# 8    1804  New Delhi   India     25.68
# 9    1805  New Delhi   India     25.30
# 10   1806  New Delhi   India     25.22
# 11   1807  New Delhi   India     24.97
# 12   1808  New Delhi   India       NaN
# 13   1809  New Delhi   India       NaN
# 14   1810  New Delhi   India       NaN
# 15   1811  New Delhi   India       NaN
# 16   1812  New Delhi   India       NaN
# 17   1813  New Delhi   India     24.56
# 18   1814  New Delhi   India     23.73
# 19   1815  New Delhi   India     24.09
# 20   1816  New Delhi   India     23.70
# 21   1817  New Delhi   India     23.86
# 22   1818  New Delhi   India     24.37
# ...

# %%
copy_csv('Global Data.csv')

# %%
Global_Data = pd.read_csv('copy_of_Global Data.csv', index_col = False)

# %%
Global_Data.head()
# Out:
#    Unnamed: 0  year  avg_temp
# 0           0  1750      8.72
# 1           1  1751      7.98
# 2           2  1752      5.78
# 3           3  1753      8.39
# 4           4  1754      8.47

# %%
NewDelhi_Data['Moving Average'] = ''

# %%
NewDelhi_Data.head()
# Out:
#    year       city country  avg_temp Moving Average
# 0  1796  New Delhi   India     25.03
# 1  1797  New Delhi   India     26.71
# 2  1798  New Delhi   India     24.29
# 3  1799  New Delhi   India     25.28
# 4  1800  New Delhi   India     25.21

# %%
NewDelhi_Data = NewDelhi_Data.drop('Moving Average', axis = 1)

# %%
NewDelhi_Data.head()
# Out:
#    year       city country  avg_temp
# 0  1796  New Delhi   India     25.03
# 1  1797  New Delhi   India     26.71
# 2  1798  New Delhi   India     24.29
# 3  1799  New Delhi   India     25.28
# 4  1800  New Delhi   India     25.21

# %%
NewDelhi_Data['Moving Average'] = NewDelhi_Data.iloc[:,3].rolling(window=7).mean()

# %%
NewDelhi_Data
# Out:
#      year       city country  avg_temp  Moving Average
# 0    1796  New Delhi   India     25.03             NaN
# 1    1797  New Delhi   India     26.71             NaN
# 2    1798  New Delhi   India     24.29             NaN
# 3    1799  New Delhi   India     25.28             NaN
# 4    1800  New Delhi   India     25.21             NaN
# 5    1801  New Delhi   India     24.22             NaN
# 6    1802  New Delhi   India     25.63       25.195714
# 7    1803  New Delhi   India     25.38       25.245714
# 8    1804  New Delhi   India     25.68       25.098571
# 9    1805  New Delhi   India     25.30       25.242857
# 10   1806  New Delhi   India     25.22       25.234286
# 11   1807  New Delhi   India     24.97       25.200000
# 12   1808  New Delhi   India       NaN             NaN
# 13   1809  New Delhi   India       NaN             NaN
# 14   1810  New Delhi   India       NaN             NaN
# 15   1811  New Delhi   India       NaN             NaN
# ...

# %%
NewDelhi_Data = NewDelhi_Data.dropna()

# %%
NewDelhi_Data
# Out:
#      year       city country  avg_temp  Moving Average
# 6    1802  New Delhi   India     25.63       25.195714
# 7    1803  New Delhi   India     25.38       25.245714
# 8    1804  New Delhi   India     25.68       25.098571
# 9    1805  New Delhi   India     25.30       25.242857
# 10   1806  New Delhi   India     25.22       25.234286
# 11   1807  New Delhi   India     24.97       25.200000
# 23   1819  New Delhi   India     23.90       24.030000
# 24   1820  New Delhi   India     24.12       23.967143
# 25   1821  New Delhi   India     24.83       24.124286
# 26   1822  New Delhi   India     24.93       24.244286
# 27   1823  New Delhi   India     24.63       24.377143
# 28   1824  New Delhi   India     25.30       24.582857
# 29   1825  New Delhi   India     25.11       24.688571
# 30   1826  New Delhi   India     25.12       24.862857
# 31   1827  New Delhi   India     25.36       25.040000
# 32   1828  New Delhi   India     24.90       25.050000
# ...

# %%
NewDelhi_Data = pd.read_csv('New Delhi Data.csv', index_col=False)

# %%
NewDelhi_Data.head()
# Out:
#    year       city country  avg_temp
# 0  1796  New Delhi   India     25.03
# 1  1797  New Delhi   India     26.71
# 2  1798  New Delhi   India     24.29
# 3  1799  New Delhi   India     25.28
# 4  1800  New Delhi   India     25.21

# %%
fill_data = NewDelhi_Data['avg_temp'].mean()

# %%
fill_data
# Out:
# 25.16626865671644

# %%
NewDelhi_Data['avg_temp'].fillna(fill_data, inplace = True)

# %%
NewDelhi_Data
# Out:
#      year       city country   avg_temp
# 0    1796  New Delhi   India  25.030000
# 1    1797  New Delhi   India  26.710000
# 2    1798  New Delhi   India  24.290000
# 3    1799  New Delhi   India  25.280000
# 4    1800  New Delhi   India  25.210000
# 5    1801  New Delhi   India  24.220000
# 6    1802  New Delhi   India  25.630000
# 7    1803  New Delhi   India  25.380000
# 8    1804  New Delhi   India  25.680000
# 9    1805  New Delhi   India  25.300000
# 10   1806  New Delhi   India  25.220000
# 11   1807  New Delhi   India  24.970000
# 12   1808  New Delhi   India  25.166269
# 13   1809  New Delhi   India  25.166269
# 14   1810  New Delhi   India  25.166269
# 15   1811  New Delhi   India  25.166269
# 16   1812  New Delhi   India  25.166269
# 17   1813  New Delhi   India  24.560000
# 18   1814  New Delhi   India  23.730000
# 19   1815  New Delhi   India  24.090000
# 20   1816  New Delhi   India  23.700000
# 21   1817  New Delhi   India  23.860000
# ...

# %%
NewDelhi_Data['Moving Average'] = NewDelhi_Data.iloc[:,3].rolling(window=7).mean()

# %%
NewDelhi_Data
# Out:
#      year       city country   avg_temp  Moving Average
# 0    1796  New Delhi   India  25.030000             NaN
# 1    1797  New Delhi   India  26.710000             NaN
# 2    1798  New Delhi   India  24.290000             NaN
# 3    1799  New Delhi   India  25.280000             NaN
# 4    1800  New Delhi   India  25.210000             NaN
# 5    1801  New Delhi   India  24.220000             NaN
# 6    1802  New Delhi   India  25.630000       25.195714
# 7    1803  New Delhi   India  25.380000       25.245714
# 8    1804  New Delhi   India  25.680000       25.098571
# 9    1805  New Delhi   India  25.300000       25.242857
# 10   1806  New Delhi   India  25.220000       25.234286
# 11   1807  New Delhi   India  24.970000       25.200000
# 12   1808  New Delhi   India  25.166269       25.335181
# 13   1809  New Delhi   India  25.166269       25.268934
# 14   1810  New Delhi   India  25.166269       25.238401
# 15   1811  New Delhi   India  25.166269       25.165011
# ...

# %%
Global_Data = pd.read_csv('Global Data.csv', index_col = False)

# %%
Global_Data.head()
# Out:
#    year  avg_temp
# 0  1750      8.72
# 1  1751      7.98
# 2  1752      5.78
# 3  1753      8.39
# 4  1754      8.47

# %%
Global_Data['Moving Average'] = Global_Data.iloc[:,1].rolling(window=7).mean()

# %%
Global_Data
# Out:
#      year  avg_temp  Moving Average
# 0    1750      8.72             NaN
# 1    1751      7.98             NaN
# 2    1752      5.78             NaN
# 3    1753      8.39             NaN
# 4    1754      8.47             NaN
# 5    1755      8.36             NaN
# 6    1756      8.85        8.078571
# 7    1757      9.02        8.121429
# 8    1758      6.74        7.944286
# 9    1759      7.99        8.260000
# 10   1760      7.19        8.088571
# 11   1761      8.77        8.131429
# 12   1762      8.61        8.167143
# 13   1763      7.50        7.974286
# 14   1764      8.40        7.885714
# 15   1765      8.25        8.101429
# 16   1766      8.41        8.161429
# 17   1767      8.22        8.308571
# 18   1768      6.78        8.024286
# 19   1769      7.69        7.892857
# 20   1770      7.69        7.920000
# 21   1771      7.85        7.841429
# 22   1772      8.19        7.832857
# 23   1773      8.22        7.805714
# 24   1774      8.77        7.884286
# ...

# %%
Global_Data_Cleaned = Global_Data[(Global_Data['year']>1801) and (Global_Data['year']<= 2013)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-42d0fb18f92b> in <module>
# ----> 1 Global_Data_Cleaned = Global_Data[(Global_Data['year']>1801) and (Global_Data['year']<= 2013)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
Global_Data_Cleaned.reset_index(drop = True)

# %%
NewDelhi_Data_Cleaned = NewDelhi_Data[NewDelhi_Data['year']>1801]

# %%
NewDelhi_Data_Cleaned.reset_index(drop = True)

# %%
Global_Data_Cleaned = Global_Data[Global_Data['year']<= 2013]

# %%
Global_Data_Cleaned = Global_Data_Cleaned[Global_Data_Cleaned['year']>1801]

# %%
Global_Data_Cleaned.reset_index(drop = True)

# %%
x = NewDelhi_Data_Cleaned['year']
y1 = NewDelhi_Data_Cleaned['Moving Average']
y2 = Global_Data_Cleaned['Moving Average']

# %%
fig = plt.plot(x, y1, lw=3, color ='blue' , label = 'New Delhi')
fig = plt.plot(x,y2, lw=3, color = 'orange' , label = 'World')
plt.xlabel('Year ', fontsize = 10)
plt.ylabel("Temp ("+chr(176)+'C)', fontsize = 10)
plt.legend(loc = 'best')
plt.savefig('Comparison.png')

# %%
std_NewDelhi = np.std(NewDelhi_Data_Cleaned['avg_temp'])
std_Global = np.std(Global_Data_Cleaned['avg_temp'])

# %%
type(std_NewDelhi)
# Out:
# float

# %%
std_NewDelhi
# Out:
# 0.5600193496906384

# %%
cov1 = np.cov(NewDelhi_Data_Cleaned['avg_temp'],Global_Data_Cleaned['avg_temp'])

# %%
cov1
# Out:
# array([[0.31510803, 0.2249239 ],
#        [0.2249239 , 0.30886117]])

# %%
cov_coeff = cov1 / ((std_NewDelhi * std_Global))

# %%
cov_coeff
# Out:
# array([[1.01484913, 0.72439863],
#        [0.72439863, 0.99473026]])
